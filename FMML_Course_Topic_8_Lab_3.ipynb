# %% [markdown]
# <a href="https://colab.research.google.com/github/kovvurisuryavenkatareddy/Fmml-Course-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 03:54:18--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  --.-KB/s    in 0.1s
#
# 2023-05-05 03:54:19 (472 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15634  1511.08630v2  Neural network models have been demonstrated t...    cs
# 29901  1711.00164v3  We demonstrate that many detection methods are...    cs
# 8828   1504.04802v1  Our understanding about things is conceptual. ...    cs
# 6933   1707.07708v2  Differential privacy (DP), ever since its adve...  stat
# 11353  1511.00146v3  Several recent works have explored stochastic ...  stat
# ...             ...                                                ...   ...
# 11170   1411.4070v1  Research on probabilistic models of networks n...  stat
# 30025  1711.05611v1  The success of recent deep convolutional neura...    cs
# 22415  1606.04366v2  In this paper we develop a method for learning...  stat
# 21745   1406.3824v3  Crowdsourcing is a popular paradigm for effect...  stat
# 22769  1706.02829v4  Time series analysis is used to understand and...  stat
#
#                                                    title  year  \
# 15634    A C-LSTM Neural Network for Text Classification  2015
# 29901  Improving Object Localization with Fitness NMS...  2017
# 8828   Gradual Classical Logic for Attributed Objects...  2015
# 6933   Per-instance Differential Privacy and the Adap...  2017
# 11353  Faster Stochastic Variational Inference using ...  2015
# ...                                                  ...   ...
# 11170  A unified view of generative models for networ...  2014
# 30025  Interpreting Deep Visual Representations via N...  2017
# 22415  Recursive nonlinear-system identification usin...  2016
# 21745  Spectral Methods meet EM: A Provably Optimal A...  2014
# 22769      Time Series Using Exponential Smoothing Cells  2017
#
#                                                 keywords
# 15634  [demonstrated, achieving, remarkable, performa...
# 29901  [demonstrate, detection, sufficently, availabl...
# 8828   [understanding, conceptual, referring, manipul...
# 6933   [differential, controversial, protection, indi...
# 11353  [stochastic, variational, inference, variation...
# ...                                                  ...
# 11170  [probabilistic, including, sociology, statisti...
# 30025  [convolutional, representations, summarize, im...
# 22415  [nonlinear, modelling, predictor, framework, l...
# 21745  [crowdsourcing, effectively, collecting, estim...
# 22769  [understand, processes, including, biological,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15634    [demonstrated, achieving, remarkable, performa...
# 29901    [demonstrate, detection, sufficently, availabl...
# 8828     [understanding, conceptual, referring, manipul...
# 6933     [differential, controversial, protection, indi...
# 11353    [stochastic, variational, inference, variation...
#                                ...
# 17996    [considerable, programming, languages, incompl...
# 22661    [objectives, discussions, assessments, typical...
# 9003     [linguistic, discussions, distinguish, constru...
# 22396    [traditional, stochastic, optimization, introd...
# 30520    [comprises, components, approximate, computati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8940 words.
# Out of those 4584 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b299afa4-71eb-4e58-8217-1863859e6d89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b299afa4-71eb-4e58-8217-1863859e6d89")) {                    Plotly.newPlot(                        "b299afa4-71eb-4e58-8217-1863859e6d89",                        [{"x":["outperforms","demonstrated","sentiment","recurrent","architecture","semantics","representations","understanding","strengths","languages","mainstream","different","achieving","representation","convolutional","remarkable","architectures","excellent","experimental","performance","classification","significantly","regression","conjunction","improving","investigate","properties","modification","demonstrate","following","convergence","evaluation","dimensions","additional","available","clustering","novelties","providing","maximization","accuracies","improvements","detection","localization","perspective","motivation","typically","considered","attributes","conceptual","classical","naturally","infeasible","extending","infinitely","observation","expressions","linguistically","referring","intuition","manipulate","including","presupposition","inspected","subjected","attributed","phenomena","presentation","reasonable","particulars","interesting","simulation","differential","predicted","postprocessing","practical","adaptivity","estimator","information","developed","individuals","techniques","regularization","magnitude","perturbation","separately","calculations","multiplicative","composition","criticized","favorable","distribution","invariance","generalization","protection","posterior","accurately","controversial","individual","conditioned","independence","intuitive","partially","desirable","algorithms","objectives","divergence","justification","inference","applications","functions","generalizes","parameter","variational","framework","generality","conditionally","experiments","theoretical","understood","stochastic","conjugate","formalized","probabilistic","interchangeably","processing","represent","important","importance","combining","decisions","associated","interactions","auxiliary","discovering","empirically","structure","observations","formulation","impossible","processes","difficult","superposition","reciprocity","financial","principle","instruments","relationships","algorithm","approximation","informative","introduce","guarantees","dimensional","mislabeled","statistic","conditions","correctly","determines","ultrametric","implement","intrinsically","robustness","irregularly","efficient","adjacency","multiscale","maximized","unsupervised","introduced","literature","particularly","dependency","normalized","criterion","advantages","approaches","corresponding","supervised","kernelized","compression","incorporating","dictionary","environment","representing","interacting","accompanying","interface","comparable","involving","challenge","strategies","challenging","reinforcement","significant","communicating","assignment","requiring","thousands","selection","imperfect"],"y":[262,107,53,141,219,107,238,163,18,92,5,760,87,364,402,19,118,26,370,892,507,279,102,17,99,145,221,29,563,66,109,245,38,108,292,142,2,84,27,25,127,365,56,72,24,119,128,70,22,108,64,7,26,6,62,51,5,14,18,9,252,2,4,8,9,20,10,39,1,67,74,32,53,1,129,4,23,728,199,45,420,87,59,17,31,7,18,30,2,11,200,25,102,7,31,51,4,135,23,31,31,49,44,569,34,23,6,213,420,202,23,110,67,549,14,3,592,138,29,127,6,4,142,3,294,114,394,90,100,54,116,76,14,19,81,328,62,99,17,99,159,4,2,9,64,6,60,835,111,40,334,50,183,0,6,109,27,13,0,73,11,103,1,414,11,15,5,151,138,116,75,44,29,42,94,450,144,197,9,45,42,62,131,72,13,7,44,115,53,138,104,265,124,246,3,36,53,27,161,15],"type":"bar"},{"x":["outperforms","demonstrated","sentiment","recurrent","architecture","semantics", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4584,), (4584, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.4011299435028248);'>reinforcement</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>how</span> <span style=''>to</span> <span style=''>play</span> <span style=''>text</span> <span style=''>based</span> <span style=''>games</span> <br/><br/><span style=''>The</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>optimal</span> <span style=''>control</span> <span style=''>policies</span> <span style=''>in</span> <span style=''>systems</span> <span style=''>where</span> <span style=''>action</span> <span style=''>space</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.8591549295774648);'>sentences</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>would</span> <span style=''>allow</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.6015325670498084);'>automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimisation</span> <span style=''>of</span> <span style=''>dialogue</span> <span style=''>systems</span> <span style=''>Text</span> <span style=''>based</span> <span style=''>games</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>endings</span> <span style=''>and</span> <span style=''>rewards</span> <span style=''>are</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.45355191256830596);'>promising</span> <span style=''>platform</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>since</span> <span style=''>their</span> <span style=''>feedback</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>employ</span> <span style='background-color:rgba(0, 255, 0, 0.4011299435028248);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.30030959752321984);'>techniques</span> <span style=''>to</span> <span style=''>jointly</span> <span style=''>learn</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.35612535612535606);'>representations</span> <span style=''>and</span> <span style=''>control</span> <span style=''>policies</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>general</span> <span style=''>text</span> <span style=''>game</span> <span style=''>playing</span> <span style=''>agent</span> <span style=''>testing</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalisation</span> <span style=''>and</span> <span style=''>transfer</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>showing</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>play</span> <span style=''>multiple</span> <span style=''>games</span> <span style=''>at</span> <span style=''>once</span> <span style=''>We</span> <span style=''>also</span> <span style=''>present</span> <span style=''>pyfiction</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>library</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universal</span> <span style=''>access</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3439434129089302);'>different</span> <span style=''>text</span> <span style=''>game ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>ROAD</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Space</span> <br/><br/><span style=''>For</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>it</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>naively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>the</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>rule</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>poor</span> <span style=''>results</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diverging</span> <span style=''>spectra</span> <span style=''>and</span> <span style=''>noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accumulation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>rules</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>circumvent</span> <span style=''>the</span> <span style=''>diverse</span> <span style=''>spectra</span> <span style=''>and</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>rules</span> <span style=''>to</span> <span style=''>mitigate</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accumulation</span> <span style=''>However</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biological</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>there</span> <span style=''>are</span> <span style=''>often</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>genes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responsible</span> <span style=''>for</span> <span style=''>clinical</span> <span style=''>outcomes</span> <span style=''>and</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>misclassification</span> <span style=''>rates</span> <span style=''>The</span> <span style=''>extent</span> <span style=''>of</span> <span style=''>such</span> <span style=''>error</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reductions</span> <span style=''>is</span> <span style=''>unveiled</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>misclassification</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>rule</span> <span style=''>and</span> <span style=''>th ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.5510204081632653);'>Likelihood</span> <span style=''>Free</span> <span style='background-color:rgba(255, 0, 0, 0.32273449920508746);'>Inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Population</span> <span style=''>Genetic</span> <span style=''>Data</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.7777777777777777);'>Exchangeable</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.32273449920508746);'>Inference</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>genetics</span> <span style=''>models</span> <span style=''>is</span> <span style=''>hindered</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>likelihoods</span> <span style=''>While</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>is</span> <span style=''>tackled</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.5510204081632653);'>likelihood</span> <span style=''>free</span> <span style=''>methods</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>hand</span> <span style=''>crafted</span> <span style=''>summary</span> <span style='background-color:rgba(255, 0, 0, 0.34640522875816987);'>statistics</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>In</span> <span style=''>complex</span> <span style=''>settings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>designing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>suitable</span> <span style=''>summary</span> <span style='background-color:rgba(255, 0, 0, 0.34640522875816987);'>statistics</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>problematic</span> <span style=''>and</span> <span style=''>results</span> <span style=''>are</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>such</span> <span style=''>choices</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.7777777777777777);'>exchangeable</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3946360153256704);'>representation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>genetic</span> <span style=''>data</span> <span style=''>to</span> <span style=''>work</span> <span style=''>directly</span> <span style=''>with</span> <span style=''>genotype</span> <span style=''>data</span> <span style=''>This</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.5510204081632653);'>likelihood</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.32273449920508746);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>where</span> <span style=''>a</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style=''>an</span> <span style=''>element</span> <span style=''>centric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>unifies</span> <span style=''>overlaps</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchy</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>A</span> <span style=''>pivotal</span> <span style=''>aspect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitatively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>is</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>for</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>tracking</span> <span style=''>the</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolution</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>For</span> <span style=''>example</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncovered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style=''>to</span> <span style=''>planted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clusterings</span> <span style=''>or</span> <span style=''>known</span> <span style=''>metadata</span> <span style=''>Yet</span> <span style=''>as</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>measures</span> <span style=''>have</span> <span style=''>critical</span> <span style=''>biases</span> <span style=''>which</span> <span style=''>un</span> <span style=''>dermine</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>usefulness</span> <span style=''>and</span> <span style=''>no</span> <span style=''>measure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodates</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overlapping</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07509881422924901)
# 	experimental (0.1329500538986705)
# 	processing (0.10564139417894358)
# 	representation (0.13079410707869205)
# 	segmentation (0.07330219187926698)
# 	information (0.2615882141573841)
# 	detection (0.13115343154868847)
# 	different (0.27308659719726913)
# 	recognition (0.13654329859863457)
# 	convolutional (0.14444843693855552)
#
# Some Statistics words are:
# 	stochastic (0.13287059990084282)
# 	variables (0.1383242439266237)
# 	statistical (0.14972731779871096)
# 	algorithm (0.3966286564204264)
# 	theoretical (0.1591472483886961)
# 	distribution (0.1849281110560238)
# 	estimation (0.1774913237481408)
# 	dimensional (0.19186911254338126)
# 	inference (0.20624690133862172)
# 	regression (0.17947446703024295)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="143e9344-6640-4d1f-8fee-53898393d85f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("143e9344-6640-4d1f-8fee-53898393d85f")) {                    Plotly.newPlot(                        "143e9344-6640-4d1f-8fee-53898393d85f",                        [{"x":["outperforms","demonstrated","sentiment","recurrent","architecture","semantics","representations","understanding","strengths","languages","mainstream","different","achieving","representation","convolutional","remarkable","architectures","excellent","experimental","performance","classification","significantly","regression","conjunction","improving","investigate","properties","modification","demonstrate","following","convergence","evaluation","dimensions","additional","available","clustering","novelties","providing","maximization","accuracies","improvements","detection","localization","perspective","motivation","typically","considered","attributes","conceptual","classical","naturally","infeasible","extending","infinitely","observation","expressions","linguistically","referring","intuition","manipulate","including","presupposition","inspected","subjected","attributed","phenomena","presentation","reasonable","particulars","interesting","simulation","differential","predicted","postprocessing","practical","adaptivity","estimator","information","developed","individuals","techniques","regularization","magnitude","perturbation","separately","calculations","multiplicative","composition","criticized","favorable","distribution","invariance","generalization","protection","posterior","accurately","controversial","individual","conditioned","independence","intuitive","partially","desirable","algorithms","objectives","divergence","justification","inference","applications","functions","generalizes","parameter","variational","framework","generality","conditionally","experiments","theoretical","understood","stochastic","conjugate","formalized","probabilistic","interchangeably","processing","represent","important","importance","combining","decisions","associated","interactions","auxiliary","discovering","empirically","structure","observations","formulation","impossible","processes","difficult","superposition","reciprocity","financial","principle","instruments","relationships","algorithm","approximation","informative","introduce","guarantees","dimensional","mislabeled","statistic","conditions","correctly","determines","ultrametric","implement","intrinsically","robustness","irregularly","efficient","adjacency","multiscale","maximized","unsupervised","introduced","literature","particularly","dependency","normalized","criterion","advantages","approaches","corresponding","supervised","kernelized","compression","incorporating","dictionary","environment","representing","interacting","accompanying","interface","comparable","involving","challenge","strategies","challenging","reinforcement","significant","communicating","assignment","requiring","thousands","selection","imperfect","canonical","introduces","exploring","specification","solutions","technology","highlighting","mathematical","introduction","underpinnings","geometric","probability","interpretation","evolution","functional","definition","independent","background","behaviors","iterative","generative","empirical","underlying","generated","factorized","deterministic","approximate","variables","likelihood","sequential","parameterized","dirichlet","characterizing","transition","assumptions","competitive","posteriors","controlled","parameters","prescriptions","programming","initialized","optimization","evolutionary","saturates","resulting","population","generations","resembles","profitable","initially","consistency","emphasized","possibilistic","investigates"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	mislabeled
# 	ultrametric
# 	censoring
# 	magnetoencephalographic
# 	orthogonality
# 	uncoupled
# 	replicable
# 	prognostics
# 	degeneracy
# 	recidivism
# 	eigenstructures
# 	advocated
# 	judiciously
# 	robustification
# 	repeatmulti
# 	majorizer
# 	heteroscedastic
# 	compounds
# 	sandwiched
# 	prespecified
# Some words which never appear in Statistics papers:
# 	referring
# 	presupposition
# 	inspected
# 	subjected
# 	interchangeably
# 	prescriptions
# 	possibilistic
# 	logistics
# 	credibility
# 	populated
# 	indicative
# 	thereafter
# 	photographs
# 	complementing
# 	entertaining
# 	mountains
# 	depicting
# 	homography
# 	pragmatic
# 	conversational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085086690936015e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
